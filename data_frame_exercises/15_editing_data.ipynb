# %%
import pandas as pd

# %%
professions = pd.read_csv("../../course-files/Prestige.csv", index_col='name')
professions.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %% [markdown]
# ## Edit value in single record

# %%
professions.loc['chemists', 'type'] = 'scientist'
professions.head()
# Out:
#                      education  income  women  prestige  census       type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113       prof
# general.managers         12.26   25879   4.02      69.1    1130       prof
# accountants              12.77    9271  15.70      63.4    1171       prof
# purchasing.officers      11.42    8865   9.11      56.8    1175       prof
# chemists                 14.62    8403  11.68      73.5    2111  scientist

# %% [markdown]
# ## Edit value in single column

# %%
isScientist = (professions['type'] == 'scientist')
isScientist.head()
# Out:
# name
# gov.administrators     False
# general.managers       False
# accountants            False
# purchasing.officers    False
# chemists                True
# Name: type, dtype: bool

# %%
professions.loc[isScientist, 'prestige'] = 90
professions.head()
# Out:
#                      education  income  women  prestige  census       type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113       prof
# general.managers         12.26   25879   4.02      69.1    1130       prof
# accountants              12.77    9271  15.70      63.4    1171       prof
# purchasing.officers      11.42    8865   9.11      56.8    1175       prof
# chemists                 14.62    8403  11.68      90.0    2111  scientist

# %%
professions.loc[isScientist, 'income'] *= 1.5
professions.head()
# Out:
#                      education     income  women  prestige  census       type
# name
# gov.administrators       13.11  12351.000  11.16      68.8    1113       prof
# general.managers         12.26  25879.000   4.02      69.1    1130       prof
# accountants              12.77   9271.000  15.70      63.4    1171       prof
# purchasing.officers      11.42   8865.000   9.11      56.8    1175       prof
# chemists                 14.62   9453.375  11.68      90.0    2111  scientist
